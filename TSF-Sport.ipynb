# %% [markdown]
# # The Sparks Foundation:Graduate Rotational Internship Program

# %% [markdown]
# # Data science and Bussiness Analytics Intern

# %% [markdown]
# # TASK 5- Exploratory Data Analysis - Sports

# %% [markdown]
# # NAME - Vikash Jayprakash Chaturvedi

# %% [markdown]
# # Find out the most successful team,player and factors contributing to win or loss of a team

# %%
#importing all necessary library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading dataframe into jupyter notebook
df=pd.read_csv("C:\\Users\\Vikash chaturvedi\\Downloads\\Indian Premier League\\deliveries.csv")
df1=pd.read_csv("C:\\Users\Vikash chaturvedi\\Downloads\\Indian Premier League\\matches.csv")

# %%
# Dealing with 1st dataset df
df.head() #first five row in dataset df
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.tail() #last 5 row in dataset df
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 179073  RA Jadeja   SR Watson  SL Malinga              0  ...         0
# 179074  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179075  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179076  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
# 179077  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.shape #no of rows and column in df dataset
# Out:
# (179078, 21)

# %%
df.describe() # provides  statistics summary for each numerical column in df dataset.
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.info() #it will give the information about the df dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
df.isnull().sum() #no of null value in each column in dataset df
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
df.nunique() #total no if unique value in df dataset
# Out:
# match_id            756
# inning                5
# batting_team         15
# bowling_team         15
# over                 20
# ball                  9
# batsman             516
# non_striker         511
# bowler              405
# is_super_over         2
# wide_runs             6
# bye_runs              5
# legbye_runs           6
# noball_runs           5
# penalty_runs          2
# batsman_runs          8
# extra_runs            7
# total_runs           10
# player_dismissed    487
# dismissal_kind        9
# fielder             499
# dtype: int64

# %%
df1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df1.shape
# Out:
# (756, 18)

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#this will show the total no of null value present in each column in dataset df1
#here we can see city, player_of_the_match,umpire1 ,umpire2,umpire3 conatin null value
df1.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df1["city"].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
df1[df1.city.isna()][["city"]]
df1[df1.winner.isna()][["winner"]]
# Out:
#     winner
# 300    NaN
# 545    NaN
# 570    NaN
# 744    NaN

# %%
df1.drop("umpire1" , axis=1, inplace=True) #drop umpire1 coulmn

# %%
df1.drop("umpire2" , axis=1, inplace=True) #drop umpire2 coulmn

# %%
 df1.drop("umpire3" , axis=1, inplace=True) #drop umpire3 coulmn

# %%
df1.shape #perviously the shape of df1 is (756, 18)
# Out:
# (756, 15)

# %%
df1.dropna(subset = ["winner"], inplace = True)

# %%
df1.dropna(subset = ["city"], inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 755
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               745 non-null    int64
#  1   season           745 non-null    int64
#  2   city             745 non-null    object
#  3   date             745 non-null    object
#  4   team1            745 non-null    object
#  5   team2            745 non-null    object
#  6   toss_winner      745 non-null    object
#  7   toss_decision    745 non-null    object
#  8   result           745 non-null    object
#  9   dl_applied       745 non-null    int64
#  10  winner           745 non-null    object
#  11  win_by_runs      745 non-null    int64
#  12  win_by_wickets   745 non-null    int64
#  13  player_of_match  745 non-null    object
#  14  venue            745 non-null    object
# dtypes: int64(5), object(10)
# memory usage: 93.1+ KB

# %%
df1.isnull().sum()  #here there is no null value present in df1
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# dtype: int64

# %%
df_merge = pd.merge(df,df1,left_on="match_id", right_on="id") #i have merge df and df1 dataset

# %%
df_merge.head() #it will show first 5 row in df_merge dataset
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...
#
#                          team2                  toss_winner  toss_decision  \
# ...

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177006 entries, 0 to 177005
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          177006 non-null  int64
#  1   inning            177006 non-null  int64
#  2   batting_team      177006 non-null  object
#  3   bowling_team      177006 non-null  object
#  4   over              177006 non-null  int64
#  5   ball              177006 non-null  int64
#  6   batsman           177006 non-null  object
#  7   non_striker       177006 non-null  object
#  8   bowler            177006 non-null  object
#  9   is_super_over     177006 non-null  int64
#  10  wide_runs         177006 non-null  int64
#  11  bye_runs          177006 non-null  int64
#  12  legbye_runs       177006 non-null  int64
#  13  noball_runs       177006 non-null  int64
#  14  penalty_runs      177006 non-null  int64
#  15  batsman_runs      177006 non-null  int64
# ...

# %%
null_percent=df_merge.isnull().sum()/df_merge.shape[0]*100
null_percent
# Out:
# match_id             0.000000
# inning               0.000000
# batting_team         0.000000
# bowling_team         0.000000
# over                 0.000000
# ball                 0.000000
# batsman              0.000000
# non_striker          0.000000
# bowler               0.000000
# is_super_over        0.000000
# wide_runs            0.000000
# bye_runs             0.000000
# legbye_runs          0.000000
# noball_runs          0.000000
# penalty_runs         0.000000
# batsman_runs         0.000000
# extra_runs           0.000000
# total_runs           0.000000
# player_dismissed    95.066834
# dismissal_kind      95.066834
# fielder             96.402947
# id                   0.000000
# season               0.000000
# city                 0.000000
# date                 0.000000
# team1                0.000000
# team2                0.000000
# toss_winner          0.000000
# toss_decision        0.000000
# result               0.000000
# dl_applied           0.000000
# ...

# %%
df_merge.describe()
# Out:
#             match_id         inning           over           ball  \
# count  177006.000000  177006.000000  177006.000000  177006.000000
# mean     1814.656277       1.483752      10.164576       3.615725
# std      3485.924763       0.502128       5.676414       1.806999
# min         1.000000       1.000000       1.000000       1.000000
# 25%       188.000000       1.000000       5.000000       2.000000
# 50%       375.000000       1.000000      10.000000       4.000000
# 75%       569.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  177006.000000  177006.000000  177006.000000  177006.000000
# mean        0.000458       0.036705       0.004926       0.021095
# std         0.021387       0.250539       0.116581       0.194661
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Visulization of data

# %%
plt. figure(figsize=(16,8))
sns. countplot(x="season",data=df1)
plt.title('Number of matches played in each season', fontsize=15) 
plt.xlabel('season', fontsize=15)
plt.ylabel ('Number of matches', fontsize=15)
# Out:
# Text(0, 0.5, 'Number of matches')

# %%
plt. figure (figsize=(16,8))
df1.groupby ('season')['team1'].nunique().plot(kind='bar', color='m')
plt.title('Team played in each season', fontsize=15) 
plt.xlabel ('season', fontsize=15)
plt.ylabel ('Number of Team', fontsize=15)
# Out:
# Text(0, 0.5, 'Number of Team')

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='venue',data=df1 ,order=df1['venue'].value_counts().index)
plt.title('Venue which hosted most number of IPL matches', fontsize=15)
plt.xlabel('Venue', fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Number of matches', fontsize=15)
# Out:
# Text(0, 0.5, 'Number of matches')

# %%
winning_teams = df1[['season','winner']]
winner_team ={}
for i in sorted(winning_teams.season.unique()):
    winner_team[i] = winning_teams[winning_teams.season ==i]['winner'].tail(1).values[0]
    
winner_IPL = pd.Series(winner_team)
winner_IPL = pd.DataFrame(winner_IPL, columns=['winner team'])
print("Season-wise Winner",winner_IPL)
# Out:
# Season-wise Winner                 winner team
# 2008       Rajasthan Royals
# 2009        Deccan Chargers
# 2010    Chennai Super Kings
# 2011    Chennai Super Kings
# 2012  Kolkata Knight Riders
# 2013         Mumbai Indians
# 2014  Kolkata Knight Riders
# 2015         Mumbai Indians
# 2016    Sunrisers Hyderabad
# 2017         Mumbai Indians
# 2018    Chennai Super Kings
# 2019         Mumbai Indians

# %%
#FROM BELOW MAP WE CAN SAY THAT :
#Mumbai Indians have won 4 times
#Chennai Super Kings have won 3 times
#kolkata knight riders have won 2 times
#Rajasthan Royals, Sunrises Hyderabad and Deccan Chargers have won 1 time

plt.figure(figsize=(16,8))
winner_IPL['winner team'].value_counts().plot(kind='bar', color='b')
plt.title('Winner of IPL across 11 seasons', fontsize=15)
plt.xlabel('Team', fontsize=15)
plt.ylabel('Number of seasons', fontsize=15)
# Out:
# Text(0, 0.5, 'Number of seasons')

# %% [markdown]
# # Impact of toss on Winning or Lossing

# %%
#In below graph we can see the team who choose to field first has won maximun no of matches
plt.title('Impact of Toss decision in Winning')
plt.ylabel('No. of Matches Won')
result1 = ['Toss decision - Field', 'Toss decision - Bat']
count1 = [df1[df1.toss_decision == 'field'].winner.count(), 
df1[df1.toss_decision == 'bat'].winner.count()]
plt.bar(result1, count1,)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # Top players with most man of the match

# %%
#FROM BELO GRAPH WE CAN SAY THAT:
#Top 10 player got most man of the match award
#Most man of the match trophy goes to CH GAYLE
#After that AB de villiers

plt.figure(figsize=(16,8))
sns.countplot(x='player_of_match',data = df1,order=df1['player_of_match'].value_counts().head(15).index , palette='rainbow')
plt.title('Top 10 players with most man of the match ', fontsize=15)
plt.xlabel('Players', fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Frequency', fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Player played highest no of dot ball

# %%
batsman =df["batsman"]
total_run =df["total_runs"]
dot_ball = df.batsman[df_merge.total_runs==0].value_counts()
dot_ball.head(10)
# Out:
# V Kohli       1369
# S Dhawan      1319
# RG Sharma     1291
# CH Gayle      1236
# RV Uthappa    1223
# SK Raina      1221
# G Gambhir     1170
# DA Warner     1114
# AM Rahane     1096
# SR Watson     1017
# Name: batsman, dtype: int64

# %% [markdown]
# # Number of match won by batting or bowling first

# %%
df1['win_by']=np.where(df1['win_by_runs']>0,'Bat first','Bowl first')

# %%
plt.figure(figsize = (18,10))
sns.countplot(x='season',hue='win_by',data=df1,palette='Blues')
plt.title("Numbers of matches won by batting and bowling first ",fontsize=20)
plt.xlabel("Season",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.show()

# %%
#In below graph we see the out of 12 ipl final match 9 times the team that won the toss was also the winner of IPL.
plt.figure(figsize = (18,10))
sns.countplot(x='season',hue='toss_decision',data=df1,palette='Purples')
plt.title("Numbers of matches won by Toss result ",fontsize=20)
plt.xlabel("Season",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.show()

# %% [markdown]
# # Top 10 player in ipl with most run

# %%
#using merged dataset (df1 and df)
df.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(16,8), color='orange')
plt.title('Top Run Getters of IPL', fontsize=15)
plt.xlabel('Batsmen', fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Total runs scored', fontsize=15)
# Out:
# Text(0, 0.5, 'Total runs scored')

# %% [markdown]
# # Top 10 player who take most wicket in IPL

# %%
#FROM BELOW GRAPH WE CAN SEE THAT:
#Top 10 player taken most of the wicket
#Malinga has taken the most number of wickets in IPL followed by Bravo and Amit Mishra
df.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(10).plot(kind='bar', figsize=(16,8), color='purple')
plt.title('Top 10 Wicket takers of IPL', fontsize=15)
plt.xlabel('Bowlers', fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Total Wicket Taken', fontsize=15)
# Out:
# Text(0, 0.5, 'Total Wicket Taken')

# %%
#DIFFERENT TYPES OF DISMISSLE IN IPL
#caught out
#bowled
#run out
#lbw
#stumped
#caught and bowled
#retired hurt
#hit wicket
#obstructing the field

plt.figure(figsize=(16,8))
dismissal_type = df.dismissal_kind.value_counts()
sns.barplot(x = dismissal_type.index, y = dismissal_type,palette="mako")
plt.title('Types of Dismissal in all seasons of IPL', fontsize=15)
plt.xlabel('Types of Dismissal', fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Frequency', fontsize=15)
plt.show()

# %% [markdown]
# # Batsman who played most of season

# %%
#we can see CH Gayle and SR Watson played total 11 season 
#KA Pollard and DA warner played 10 season
no_of_balls = pd.DataFrame(df.groupby('batsman')['ball'].count())
runs = pd.DataFrame(df_merge.groupby('batsman')['batsman_runs'].sum())
seasons = pd.DataFrame(df_merge.groupby('batsman')['season'].nunique())

strike_rate = pd.DataFrame({'balls':no_of_balls['ball'], 'run':runs['batsman_runs'], 'season':seasons['season']})
strike_rate.reset_index(inplace = True)
strike_rate['strike_rate'] = (strike_rate['run']/strike_rate['balls'])*100
highest_strike_rate = strike_rate[strike_rate.season.isin([9,10,11])][['season','batsman','strike_rate']].sort_values(by='strike_rate',ascending = False)
highest_strike_rate.head()
# Out:
#      season     batsman  strike_rate
# 92       11    CH Gayle   145.640370
# 213      10  KA Pollard   141.751527
# 112      10   DA Warner   139.523249
# 444      11   SR Watson   136.945813
# 188       9   JA Morkel   136.938202

# %% [markdown]
# # Toss_winner,Toss_decision and Winner in final match

# %%
final_matches=df1.drop_duplicates(subset=['season'], keep='last')
final_matches[['toss_winner','toss_decision','winner']].reset_index(drop=True)
# Out:
#                     toss_winner toss_decision                 winner
# 0                Mumbai Indians           bat         Mumbai Indians
# 1              Rajasthan Royals         field       Rajasthan Royals
# 2   Royal Challengers Bangalore         field        Deccan Chargers
# 3           Chennai Super Kings           bat    Chennai Super Kings
# 4           Chennai Super Kings           bat    Chennai Super Kings
# 5           Chennai Super Kings           bat  Kolkata Knight Riders
# 6                Mumbai Indians           bat         Mumbai Indians
# 7         Kolkata Knight Riders         field  Kolkata Knight Riders
# 8           Chennai Super Kings         field         Mumbai Indians
# 9           Sunrisers Hyderabad           bat    Sunrisers Hyderabad
# 10          Chennai Super Kings         field    Chennai Super Kings
# 11               Mumbai Indians           bat         Mumbai Indians

# %%
#from below graph we can say that:
#Gayle and Pollard have the highest strike rates in IPL.
plt.figure(figsize=(16,8))
sns.barplot(x='batsman', y='strike_rate', data=highest_strike_rate.head(10), hue='season')
plt.title('Highest Strike rate player of IPL', fontsize=15)
plt.xlabel('Player', fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Strike Rate', fontsize=15)
# Out:
# Text(0, 0.5, 'Strike Rate')

# %% [markdown]
# # Total number of runs score in each ipl season

# %%
#from below graph we can say that:
#In year 2008 more that 16000 runs scored
#In year 2009 run scored between 14000 to 16000
#Highest run scored in a season is 2013 (more than 21000)
df_merge.groupby('season')['batsman_runs'].sum().plot(kind='bar',figsize=(16,8), color='y' )
plt.title('Total scoring runs over the seasons of IPL', fontsize=15)
plt.xlabel('Seasons', fontsize=15)
plt.ylim(10000,22000)
plt.ylabel('Total runs', fontsize=15)
# Out:
# Text(0, 0.5, 'Total runs')

# %% [markdown]
# # Conclusion

# %%
# The highest number of match won by Mumbai Indians.
# Teams which Bowl first has higher chances of winning then the team which bat first.
# Highest wicket taker in ipl is SL Malinga
# Top leading run scorer in IPL are Virat kholi, SK Raina, RG Sharma.
# CH Gayle have highest man of the match award in ipl
# In finals most teams after winning toss decide to do fielding first as it increses chance of winning while chassing runs.
# It is interesting that out of 12 IPL finals,9 times the team that won the toss was also the winner of IPL.
# Highest number of match played in the year 2013
# Highest number of run score in season 2013
# Highest number of team played in the year 2011
